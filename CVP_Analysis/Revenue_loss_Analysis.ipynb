# %% [markdown]
# **Total Revenue Loss**
#
# Revenue Loss = (room rate(ADR)* number of cancelled) + no-show bookings

# %%
import pandas as pd

# %%
# Load the train dataset
df = pd.read_csv('/content/drive/MyDrive/Data Science Life Cycle/Hotel_A_Train_Cleaned (1).csv')
df
# Out:
#        Reservation-id  Age Expected_checkin Expected_checkout Booking_date  \
# 0            39428300   40       2015-07-01        2015-07-02   2015-05-21
# 1            77491756   49       2015-07-01        2015-07-02   2015-05-26
# 2            73747291   42       2015-07-02        2015-07-06   2015-06-29
# 3            67301739   25       2015-07-02        2015-07-03   2015-06-20
# 4            77222321   62       2015-07-03        2015-07-04   2015-06-20
# ...               ...  ...              ...               ...          ...
# 26984        15645505   49       2016-08-31        2016-09-01   2016-07-25
# 26985        56414525   49       2016-08-31        2016-09-01   2016-04-26
# 26986        52023375   49       2016-09-01        2016-09-02   2016-08-23
# 26987        98041387   65       2016-08-31        2016-09-01   2016-05-25
# 26988        55243988   48       2016-08-31        2016-09-01   2016-06-27
#
#        Adults  Children  Babies  Reservation_Status  Discount_Rate  ...  \
# 0           2         2       0                   1             10  ...
# 1           3         3       0                   1              0  ...
# 2           3         3       0                   1              0  ...
# 3           4         3       0                   1              5  ...
# 4           1         1       0                   1             10  ...
# ...       ...       ...     ...                 ...            ...  ...
# 26984       1         2       1                   1             10  ...
# 26985       2         1       0                   3             40  ...
# 26986       2         1       1                   1              5  ...
# 26987       3         2       0                   2             20  ...
# 26988       3         1       0                   3              0  ...
#
#        Meal_Type_FB  Meal_Type_HB  Visted_Previously_YES  \
# 0             False         False                  False
# 1             False         False                  False
# 2             False         False                  False
# 3             False         False                  False
# 4             False         False                  False
# ...             ...           ...                    ...
# 26984         False          True                   True
# 26985         False         False                  False
# 26986         False          True                  False
# 26987          True         False                  False
# 26988         False          True                  False
#
#        Previous_Cancellations_YES  Deposit_type_NON-REFUNDABLE  \
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                           False                        False
# ...                           ...                          ...
# 26984                        True                        False
# 26985                       False                        False
# 26986                       False                        False
# 26987                       False                        False
# 26988                       False                        False
#
#        Deposit_type_REFUNDABLE  Booking_channel_DIRECT  \
# 0                        False                   False
# 1                         True                   False
# 2                        False                   False
# 3                         True                   False
# 4                        False                    True
# ...                        ...                     ...
# 26984                    False                   False
# 26985                     True                   False
# 26986                    False                    True
# 26987                    False                   False
# 26988                    False                   False
#
#        Booking_channel_ONLINE  Required_Car_Parking_YES  Use_Promotion_YES
# 0                        True                      True               True
# 1                        True                      True              False
# 2                        True                      True              False
# 3                       False                      True               True
# 4                       False                     False               True
# ...                       ...                       ...                ...
# 26984                    True                      True               True
# 26985                   False                      True               True
# 26986                   False                      True               True
# 26987                    True                     False               True
# 26988                    True                     False              False
#
# [26989 rows x 41 columns]

# %%
# Filter cancelled + no-show
cancelled_df = df[df['Reservation_Status'].isin([2, 3])]

# Calculate revenue loss
total_revenue_loss = cancelled_df['Room_Rate'].sum()

print("Total Revenue Loss: $", total_revenue_loss)
# Out:
# Total Revenue Loss: $ 1089430

# %% [markdown]
# **Revenue Loss by Age, Country, Region**
#
# A) Revenue Loss by Age Group

# %%
df['age_group'] = pd.cut(df['Age'],
                         bins=[18,30,45,70],
                         labels=['18-30','30-45','45-70'])

# %%
# Add 'age_group' to cancelled_df if it's missing, by mapping from df
if 'age_group' not in cancelled_df.columns:
    # It's important to make a copy to avoid SettingWithCopyWarning
    # and ensure modifications are made on a standalone DataFrame.
    cancelled_df = cancelled_df.copy()
    cancelled_df['age_group'] = df['age_group'].loc[cancelled_df.index]

age_loss = cancelled_df.groupby('age_group', observed=False)['Room_Rate'].sum().reset_index()
print(age_loss)
# Out:
#   age_group  Room_Rate
# 0     18-30     251827
# 1     30-45     310167
# 2     45-70     512109

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.barplot(data=age_loss, x='age_group', y='Room_Rate')
plt.title("Revenue Loss by Age Group")
plt.ylabel("Revenue Loss (£)")
plt.show()

# %% [markdown]
# B) Revenue Loss by Day

# %%
import pandas as pd
# Load the train dataset
df = pd.read_csv('/content/drive/MyDrive/Data Science Life Cycle/Hotel_A_Train_Cleaned (1).csv')

df['Day_Type'] = df['Is_Weekend'].map({
    True: 'Weekend',
    False: 'Weekday'
})

# %%
loss_df = df[df['Reservation_Status'].isin([2,3])].copy()
loss_df['Day_Type'] = loss_df['Is_Weekend'].astype(int).map({
    1: 'Weekend',
    0: 'Weekday'
})

# %%
avg_loss = cancelled_df["Room_Rate"].mean()
print("Average Revenue Loss:", avg_loss)
# Out:
# Average Revenue Loss: 175.9017560512577

# %%
df['is_cancelled'] = df['Reservation_Status'].isin([2,3])
weekend_cancel = df.groupby('Is_Weekend')['is_cancelled'].mean() * 100
print(weekend_cancel)
# Out:
# Is_Weekend
# 0    21.727994
# 1    26.973684
# Name: is_cancelled, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Convert the Series to a DataFrame for easier plotting
weekend_cancel_df_combined = weekend_cancel.reset_index()
weekend_cancel_df_combined.columns = ['Is_Weekend', 'Combined_Cancellation_NoShow_Percentage']

# Map 0 and 1 to 'Weekday' and 'Weekend'
weekend_cancel_df_combined['Day_Type'] = weekend_cancel_df_combined['Is_Weekend'].map({
    0: 'Weekday',
    1: 'Weekend'
})

plt.figure(figsize=(7, 5))
sns.barplot(data=weekend_cancel_df_combined, x='Day_Type', y='Combined_Cancellation_NoShow_Percentage', hue='Day_Type', palette='viridis', legend=False)
plt.title('Combined Cancellation & No-Show Percentage: Weekend vs. Weekday')
plt.xlabel('Day Type')
plt.ylabel('Percentage (%)')
plt.ylim(0, weekend_cancel_df_combined['Combined_Cancellation_NoShow_Percentage'].max() * 1.1)
plt.show()

# %% [markdown]
# C) Revenue Loss by lead time

# %%
max_lead = df['Lead_Time'].max()
print("Highest Lead Time:", max_lead)
# Out:
# Highest Lead Time: 708

# %%
df[df['Lead_Time'] == df['Lead_Time'].max()]
# Out:
#       Reservation-id  Age Expected_checkin Expected_checkout Booking_date  \
# 3921        81524080   65       2016-03-24        2016-03-25   2014-04-16
#
#       Adults  Children  Babies  Reservation_Status  Discount_Rate  ...  \
# 3921       5         1       0                   1             25  ...
#
#       Meal_Type_FB  Meal_Type_HB  Visted_Previously_YES  \
# 3921         False          True                  False
#
#       Previous_Cancellations_YES  Deposit_type_NON-REFUNDABLE  \
# 3921                       False                        False
#
#       Deposit_type_REFUNDABLE  Booking_channel_DIRECT  Booking_channel_ONLINE  \
# 3921                    False                   False                    True
#
#       Required_Car_Parking_YES  Use_Promotion_YES
# 3921                      True               True
#
# [1 rows x 41 columns]

# %%
bins = [0, 14, 60, 708]
labels = ['Short', 'Medium', 'Long']

df['Lead_Time_Group'] = pd.cut(df['Lead_Time'],
                              bins=bins,
                              labels=labels,
                              include_lowest=True)

# %%
df['Lead_Time_Group'].value_counts()
# Out:
# Lead_Time_Group
# Long      18662
# Medium     6234
# Short      2093
# Name: count, dtype: int64

# %%
lead_time_loss = loss_df.groupby(['Lead_Time_Group', 'Reservation_Status'])['Room_Rate'] \
       .sum().reset_index()
lead_time_loss['Status_Label'] = lead_time_loss['Reservation_Status'].map({
    2: 'Canceled',
    3: 'No-Show'
})
# Out:
# /tmp/ipykernel_522/3973911318.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   lead_time_loss = loss_df.groupby(['Lead_Time_Group', 'Reservation_Status'])['Room_Rate'] \

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.barplot(
    data=lead_time_loss,
    x='Lead_Time_Group',
    y='Room_Rate',
    hue='Status_Label',
    palette={'Canceled': 'green', 'No-Show': 'blue'},
    errorbar=None
)
plt.title('Revenue Loss by Lead Time Group (Canceled vs. No-Show)')
plt.xlabel('Lead Time Group')
plt.ylabel('Total Revenue Loss (£)')
plt.legend(title='Reservation Status')
plt.show()

# %% [markdown]
# Recommendations

# %% [markdown]
# I. Cancellation % using different factors

# %%
df['is_cancelled'] = df['Reservation_Status'].isin([2])
promo_cancel = df.groupby('Use_Promotion_YES')['is_cancelled'].mean() * 100
print(promo_cancel)
# Out:
# Use_Promotion_YES
# False    15.175909
# True     15.235935
# Name: is_cancelled, dtype: float64

# %%
prev_cancel = df.groupby('Previous_Cancellations_YES')['is_cancelled'].mean() * 100
print(prev_cancel)
# Out:
# Previous_Cancellations_YES
# False    15.334782
# True     14.332354
# Name: is_cancelled, dtype: float64

# %%
channel_cancel = df.groupby('Booking_channel_ONLINE')['is_cancelled'].mean() * 100
print(channel_cancel)
# Out:
# Booking_channel_ONLINE
# False    15.223523
# True     15.219097
# Name: is_cancelled, dtype: float64

# %%
deposit_cancel = df.groupby('Deposit_type_NON-REFUNDABLE')['is_cancelled'].mean() * 100
print(deposit_cancel)
# Out:
# Deposit_type_NON-REFUNDABLE
# False    15.236095
# True     15.053763
# Name: is_cancelled, dtype: float64

# %%
cancelled_df = df[df['Reservation_Status'].isin([3])]

total_loss = cancelled_df['Room_Rate'].sum()
print("Total Revenue Loss:", total_loss)
# Out:
# Total Revenue Loss: 370625

# %%
cancelled_df = df[df['Reservation_Status'].isin([2])]

total_loss = cancelled_df['Room_Rate'].sum()
print("Total Revenue Loss:", total_loss)
# Out:
# Total Revenue Loss: 718805

# %%
loss_df = df[df['Reservation_Status'].isin([2,3])].copy()

# %%
promo_loss = loss_df.groupby(['Is_Weekend', 'Reservation_Status'])['Room_Rate'] \
       .sum().reset_index()

# %%
df['Status_Label'] = df['Reservation_Status'].map({
    2: 'Canceled',
    3: 'No-Show'
})

# %%
loss_df['Status_Label'] = df['Status_Label'].loc[loss_df.index]
lead_pct = pd.crosstab(
    loss_df['Lead_Time_Group'],
    loss_df['Status_Label'],
    normalize='index'
) * 100

# %%
loss_df.groupby(['Lead_Time_Group', 'Reservation_Status'])['Room_Rate'] \
       .sum().reset_index()
# Out:
# /tmp/ipykernel_522/3909338190.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   loss_df.groupby(['Lead_Time_Group', 'Reservation_Status'])['Room_Rate'] \
#   Lead_Time_Group  Reservation_Status  Room_Rate
# 0           Short                   2      47973
# 1           Short                   3      23067
# 2          Medium                   2     148063
# 3          Medium                   3      76627
# 4            Long                   2     522769
# 5            Long                   3     270931

# %%
loss_df.groupby(['Previous_Cancellations_YES', 'Reservation_Status'])['Room_Rate'] \
       .sum().reset_index()
# Out:
#    Previous_Cancellations_YES  Reservation_Status  Room_Rate
# 0                       False                   2     642372
# 1                       False                   3     329033
# 2                        True                   2      76433
# 3                        True                   3      41592

# %%
loss_df.groupby(['Booking_channel_ONLINE', 'Reservation_Status'])['Room_Rate'] \
       .sum().reset_index()
# Out:
#    Booking_channel_ONLINE  Reservation_Status  Room_Rate
# 0                   False                   2     309007
# 1                   False                   3     159921
# 2                    True                   2     409798
# 3                    True                   3     210704

# %%
loss_df.groupby(['Deposit_type_NON-REFUNDABLE', 'Reservation_Status'])['Room_Rate'] \
       .sum().reset_index()
# Out:
#    Deposit_type_NON-REFUNDABLE  Reservation_Status  Room_Rate
# 0                        False                   2     660636
# 1                        False                   3     339176
# 2                         True                   2      58169
# 3                         True                   3      31449

# %%
high_risk_avg = cancelled_df['Room_Rate'].mean()

deposit = high_risk_avg * 0.3   # 30%
print(deposit)
# Out:
# 52.493062317429406
